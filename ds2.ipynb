# %%
import numpy as np
import pandas as pd
import requests
import json
from sklearn.linear_model import LinearRegression 

#mahindra
csv_path='TECHM.NS.csv'
df=pd.read_csv(csv_path, nrows=10)
df.head
df_new = df.iloc[:, [1,2,3]]
df_new
print(df_new)
print("-----------------------------------------------------------------")

import matplotlib.pyplot as plt

h= df_new['High']
l= df_new['Low']

print("High :",h)
print("Low :",l)

diff=h-l
print(diff)

plt.plot(diff, linestyle='dotted')
plt.xlabel("No.of Days")
plt.ylabel("Difference Between High and Low")
plt.title("Tech Mahindra Stock - 13/06/2022 to 27/06/2022 ")
plt.show()

#tcs
csv_path='TCS.NS.csv'
df=pd.read_csv(csv_path, nrows=10)
df.head
df_n = df.iloc[:, [1,2,3]]
df_n
print(df_n)
print("-----------------------------------------------------------------")

import matplotlib.pyplot as plt

h= df_n['High']
l= df_n['Low']

print("High :",h)
print("Low :",l)

diff1=h-l
print(diff1)

plt.plot(diff1, linestyle='dotted')
plt.xlabel("No.of Days")
plt.ylabel("Difference Between High and Low")
plt.title("Tata Consultancy Services Stock - 13/06/2022 to 27/06/2022 ")
plt.show()


#both together
my_labels=["TCS", "Mahindra "]
plt.plot(diff)
plt.plot(diff1)
plt.title("Tech Mahindara VS TCS - 13/06/2022 to 27/06/2022")
plt.xlabel("No.Of Days")
plt.ylabel("Difference between High and Low")
plt.legend(my_labels)
plt.show
# Out:
#           Open         High          Low
# 0  1081.199951  1084.599976  1050.000000
# 1  1034.000000  1056.550049  1020.400024
# 2  1037.000000  1037.000000  1017.799988
# 3  1024.050049  1033.599976   971.000000
# 4   971.099976   974.349976   943.700012
# 5   965.000000   988.150024   948.049988
# 6   991.400024  1004.650024   980.000000
# 7   996.950012   996.950012   968.000000
# 8   981.099976   998.549988   971.250000
# 9  1001.000000  1001.000000   974.000000
# -----------------------------------------------------------------
# High : 0    1084.599976
# 1    1056.550049
# 2    1037.000000
# 3    1033.599976
# 4     974.349976
# 5     988.150024
# 6    1004.650024
# 7     996.950012
# 8     998.549988
# 9    1001.000000
# Name: High, dtype: float64
# Low : 0    1050.000000
# 1    1020.400024
# 2    1017.799988
# 3     971.000000
# 4     943.700012
# 5     948.049988
# 6     980.000000
# 7     968.000000
# 8     971.250000
# 9     974.000000
# Name: Low, dtype: float64
# ...
